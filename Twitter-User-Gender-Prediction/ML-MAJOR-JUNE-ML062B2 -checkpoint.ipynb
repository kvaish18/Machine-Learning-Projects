# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
#importing pandas to use the library functions

# %%
df=pd.read_csv('Information.csv', encoding = "ISO-8859-1")
#df contains the file information  which is in csv format

# %%
df
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      815719226    False   finalized                   3    10/26/15 23:24
# 1      815719227    False   finalized                   3    10/26/15 23:30
# 2      815719228    False   finalized                   3    10/26/15 23:33
# 3      815719229    False   finalized                   3    10/26/15 23:10
# 4      815719230    False   finalized                   3     10/27/15 1:15
# ...          ...      ...         ...                 ...               ...
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
# ...

# %%
df.columns
#gives the list of column names in this dataframe
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'gender', 'gender:confidence', 'profile_yn',
#        'profile_yn:confidence', 'created', 'description', 'fav_number',
#        'gender_gold', 'link_color', 'name', 'profile_yn_gold', 'profileimage',
#        'retweet_count', 'sidebar_color', 'text', 'tweet_coord', 'tweet_count',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df.info()
#gives the information about each of the column i.e regarding null values and its Dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16306 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  gender_gold            50 non-null     object
#  13  link_color             20050 non-null  object
# ...

# %%
df.shape
#gives the number of rows and columns of a dataframe in tuple format
# Out:
# (20050, 26)

# %%
df['gender_gold'].isnull().sum()
#gives the total number of NaN values for the specified index
# Out:
# 20000

# %%
df.dropna(subset=['gender','gender:confidence'], how='any', inplace=True)
#drops the rows with NaN values for the specified indices

# %%
df.shape
# Out:
# (19953, 26)

# %%
df.drop(df[df['gender']=='brand'].index,inplace=True)
df.drop(df[df['gender']=='unknown'].index,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12894 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12894 non-null  int64
#  1   _golden                12894 non-null  bool
#  2   _unit_state            12894 non-null  object
#  3   _trusted_judgments     12894 non-null  int64
#  4   _last_judgment_at      12858 non-null  object
#  5   gender                 12894 non-null  object
#  6   gender:confidence      12894 non-null  float64
#  7   profile_yn             12894 non-null  object
#  8   profile_yn:confidence  12894 non-null  float64
#  9   created                12894 non-null  object
#  10  description            11194 non-null  object
#  11  fav_number             12894 non-null  int64
#  12  gender_gold            36 non-null     object
#  13  link_color             12894 non-null  object
# ...

# %%
df['tweet_coord'].isnull().sum()
# Out:
# 12816

# %%
df.drop(['tweet_coord','gender_gold', 'profile_yn_gold'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (12894, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12894 entries, 0 to 20049
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12894 non-null  int64
#  1   _golden                12894 non-null  bool
#  2   _unit_state            12894 non-null  object
#  3   _trusted_judgments     12894 non-null  int64
#  4   _last_judgment_at      12858 non-null  object
#  5   gender                 12894 non-null  object
#  6   gender:confidence      12894 non-null  float64
#  7   profile_yn             12894 non-null  object
#  8   profile_yn:confidence  12894 non-null  float64
#  9   created                12894 non-null  object
#  10  description            11194 non-null  object
#  11  fav_number             12894 non-null  int64
#  12  link_color             12894 non-null  object
#  13  name                   12894 non-null  object
# ...

# %%
df
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      815719226    False   finalized                   3    10/26/15 23:24
# 1      815719227    False   finalized                   3    10/26/15 23:30
# 2      815719228    False   finalized                   3    10/26/15 23:33
# 3      815719229    False   finalized                   3    10/26/15 23:10
# 4      815719230    False   finalized                   3     10/27/15 1:15
# ...          ...      ...         ...                 ...               ...
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
# ...

# %%
df['tweet_location'].fillna(value='unknown', inplace=True)
df['user_timezone'].fillna(value='unknown', inplace=True)
#to fill the NaN values for the specified indices with "unknown"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12894 entries, 0 to 20049
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12894 non-null  int64
#  1   _golden                12894 non-null  bool
#  2   _unit_state            12894 non-null  object
#  3   _trusted_judgments     12894 non-null  int64
#  4   _last_judgment_at      12858 non-null  object
#  5   gender                 12894 non-null  object
#  6   gender:confidence      12894 non-null  float64
#  7   profile_yn             12894 non-null  object
#  8   profile_yn:confidence  12894 non-null  float64
#  9   created                12894 non-null  object
#  10  description            11194 non-null  object
#  11  fav_number             12894 non-null  int64
#  12  link_color             12894 non-null  object
#  13  name                   12894 non-null  object
# ...

# %%
df['description']
#gives the series for the specified index
# Out:
# 0                                    i sing my own rhythm.
# 1        I'm the author of novels filled with family dr...
# 2                      louis whining and squealing and all
# 3        Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4        Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
#                                ...
# 20045                                                 (rp)
# 20046    Whatever you like, it's not a problem at all. ...
# 20047    #TeamBarcelona ..You look lost so you should f...
# 20048    Anti-statist; I homeschool my kids. Aspiring t...
# 20049                       Teamwork makes the dream work.
# Name: description, Length: 12894, dtype: object

# %%
df['_last_judgment_at']
# Out:
# 0        10/26/15 23:24
# 1        10/26/15 23:30
# 2        10/26/15 23:33
# 3        10/26/15 23:10
# 4         10/27/15 1:15
#               ...
# 20045               NaN
# 20046               NaN
# 20047               NaN
# 20048               NaN
# 20049               NaN
# Name: _last_judgment_at, Length: 12894, dtype: object

# %%
df['description'].fillna(value='Unknown',inplace=True)
df['_last_judgment_at'].fillna(value='Unknown',inplace=True)

# %%
df.shape
# Out:
# (12894, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12894 entries, 0 to 20049
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12894 non-null  int64
#  1   _golden                12894 non-null  bool
#  2   _unit_state            12894 non-null  object
#  3   _trusted_judgments     12894 non-null  int64
#  4   _last_judgment_at      12894 non-null  object
#  5   gender                 12894 non-null  object
#  6   gender:confidence      12894 non-null  float64
#  7   profile_yn             12894 non-null  object
#  8   profile_yn:confidence  12894 non-null  float64
#  9   created                12894 non-null  object
#  10  description            12894 non-null  object
#  11  fav_number             12894 non-null  int64
#  12  link_color             12894 non-null  object
#  13  name                   12894 non-null  object
# ...

# %%
df.describe()
#gives the statistical data like count,mean,std for the numerical values in the dataframe
# Out:
#            _unit_id  _trusted_judgments  gender:confidence  \
# count  1.289400e+04        12894.000000       12894.000000
# mean   8.157298e+08            3.690631           0.916154
# std    6.190071e+03           13.067179           0.165393
# min    8.157192e+08            3.000000           0.320600
# 25%    8.157240e+08            3.000000           1.000000
# 50%    8.157302e+08            3.000000           1.000000
# 75%    8.157350e+08            3.000000           1.000000
# max    8.157580e+08          274.000000           1.000000
#
#        profile_yn:confidence     fav_number  retweet_count   tweet_count  \
# count           12894.000000   12894.000000   12894.000000  1.289400e+04
# mean                0.994840    5475.316194       0.067008  2.945312e+04
# std                 0.041333   13118.359541       1.524385  7.072127e+04
# min                 0.630800       0.000000       0.000000  1.000000e+00
# ...

# %%
df.drop(df[(df['_trusted_judgments'] >=50)].index, inplace=True)
df.drop(df[(df['retweet_count'] >=10)].index, inplace=True)   
#to remove outliers by dropping the rows with values that are greater than 50 for '_trusted_judgments'and vlaues greater than 10 for 'retweet_count'

# %%
df.duplicated().sum()
#to get the number of duplicate rows
# Out:
# 0

# %% [markdown]
# # EDA with Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib inline sets the backend of matplotlib to the 'inline' backend

# %%
df.describe()
# Out:
#            _unit_id  _trusted_judgments  gender:confidence  \
# count  1.284900e+04             12849.0       12849.000000
# mean   8.157297e+08                 3.0           0.916112
# std    6.057706e+03                 0.0           0.165479
# min    8.157192e+08                 3.0           0.320600
# 25%    8.157240e+08                 3.0           1.000000
# 50%    8.157302e+08                 3.0           1.000000
# 75%    8.157350e+08                 3.0           1.000000
# max    8.157396e+08                 3.0           1.000000
#
#        profile_yn:confidence     fav_number  retweet_count   tweet_count  \
# count           12849.000000   12849.000000   12849.000000  1.284900e+04
# mean                0.994825    5467.832438       0.041248  2.949176e+04
# std                 0.041403   13114.244434       0.307915  7.082608e+04
# min                 0.630800       0.000000       0.000000  1.000000e+00
# ...

# %%
df.shape
# Out:
# (12849, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12849 entries, 0 to 19998
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12849 non-null  int64
#  1   _golden                12849 non-null  bool
#  2   _unit_state            12849 non-null  object
#  3   _trusted_judgments     12849 non-null  int64
#  4   _last_judgment_at      12849 non-null  object
#  5   gender                 12849 non-null  object
#  6   gender:confidence      12849 non-null  float64
#  7   profile_yn             12849 non-null  object
#  8   profile_yn:confidence  12849 non-null  float64
#  9   created                12849 non-null  object
#  10  description            12849 non-null  object
#  11  fav_number             12849 non-null  int64
#  12  link_color             12849 non-null  object
#  13  name                   12849 non-null  object
# ...

# %%
df.dtypes
#gives the Dtype of each of the columns
# Out:
# _unit_id                   int64
# _golden                     bool
# _unit_state               object
# _trusted_judgments         int64
# _last_judgment_at         object
# gender                    object
# gender:confidence        float64
# profile_yn                object
# profile_yn:confidence    float64
# created                   object
# description               object
# fav_number                 int64
# link_color                object
# name                      object
# profileimage              object
# retweet_count              int64
# sidebar_color             object
# text                      object
# tweet_count                int64
# tweet_created             object
# tweet_id                 float64
# tweet_location            object
# user_timezone             object
# dtype: object

# %%
df.gender.unique()
#specifies the unique values mentioned under the specified index
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.set_index('_unit_id',inplace=True)
#sets the index of the dataframe as the specified column

# %%
df.head()
#shows the first 5 rows of the dataframe
# Out:
#            _golden _unit_state  _trusted_judgments _last_judgment_at  gender  \
# _unit_id
# 815719226    False   finalized                   3    10/26/15 23:24    male
# 815719227    False   finalized                   3    10/26/15 23:30    male
# 815719228    False   finalized                   3    10/26/15 23:33    male
# 815719229    False   finalized                   3    10/26/15 23:10    male
# 815719230    False   finalized                   3     10/27/15 1:15  female
#
#            gender:confidence profile_yn  profile_yn:confidence  \
# _unit_id
# 815719226             1.0000        yes                    1.0
# 815719227             1.0000        yes                    1.0
# 815719228             0.6625        yes                    1.0
# 815719229             1.0000        yes                    1.0
# 815719230             1.0000        yes                    1.0
#
#                   created                                        description  \
# _unit_id
# ...

# %%
df.gender.value_counts().plot(kind='bar')
#gives a bar graph which represents the number of entries with the values specified in the column

# %%
sns.boxplot(x='tweet_count', y='gender', data=df)
#reprsents the given columns in a boxplot

# %%
df.corr()
#shows the co-relation between all the columns
# Out:
#                        _golden  _trusted_judgments  gender:confidence  \
# _golden                    NaN                 NaN                NaN
# _trusted_judgments         NaN                 NaN                NaN
# gender:confidence          NaN                 NaN           1.000000
# profile_yn:confidence      NaN                 NaN           0.249948
# fav_number                 NaN                 NaN          -0.039754
# retweet_count              NaN                 NaN           0.009030
# tweet_count                NaN                 NaN          -0.058064
# tweet_id                   NaN                 NaN          -0.010495
#
#                        profile_yn:confidence  fav_number  retweet_count  \
# _golden                                  NaN         NaN            NaN
# _trusted_judgments                       NaN         NaN            NaN
# gender:confidence                   0.249948   -0.039754       0.009030
# ...

# %%
sns.heatmap(df.corr())
#represents the co-relation between all the columns using heatmap,where the darker areas show less relation

# %% [markdown]
# # QUESTIONS:

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vaishnavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords   #removing stop words 
stop = stopwords.words('english')
df['text'] = df['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['description'] = df['description'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %% [markdown]
# ##### Q1) What are the most common emotions or words used by males and females?

# %%
df1=df.loc[df['gender']=='male']
freq = pd.Series(' '.join(df1['text']).split()).value_counts()[:10]#  most common word used by male
freq
# Out:
# I       1567
# The      631
# like     316
# -        314
# get      293
# I'm      272
# And      241
# one      189
# new      176
# time     165
# dtype: int64

# %%
freq.sort_values(ascending=False)[:10].plot.barh()

# %%
df1=df.loc[df['gender']=='female']
freq = pd.Series(' '.join(df1['text']).split()).value_counts()[:10]#  most common  word used by female 
freq
# Out:
# I         2358
# The        546
# I'm        481
# like       400
# get        309
# And        284
# one        268
# love       247
# -          199
# people     197
# dtype: int64

# %%
freq.sort_values(ascending=False)[:10].plot.barh()

# %% [markdown]
# ###### So, by the plots the most common words used by males and females in the description as well as text are articles such as I, the, I am and words like : like, get , one, etc. which are common in both the genders. Hence, finding most common words does not help in predicting gender of an user.

# %%
pip install pyenchant
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'C:\Users\vaishnavi\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import enchant   #checking the number of typos made by female and male!!!
  
# create dictionary for the language 
# in use(en_US here) 
dict = enchant.Dict("en_US") 
cnt1=0
df['text'] = df['text'].replace(to_replace=r'^https?:\/\/.*[\r\n]*',value='',regex=True)
df3=df.loc[df['gender']=='female']
df3['misspelled words'] = df3['text'].apply(lambda x: len([x for x in x.split() if dict.check(x) == False ]))
ans=df3['misspelled words'].sum()


df4=df.loc[df['gender']=='male']
df4['number'] = df4['text'].apply(lambda x: len([x for x in x.split() if dict.check(x) == False ]))
ans1=df4['number'].sum()

print("Typos made by female are: ")
print(ans)
print("Typos made by male are" )
print(ans1)
# Out:
# C:\Users\vaishnavi\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Typos made by female are:
# 18588
# Typos made by male are
# 18480
# C:\Users\vaishnavi\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ###### So, the typing errors made by males and females are approximately equal, hence, this method is also not helpful in predicting gender of an user.

# %% [markdown]
# ## Ensemble Machine Learning Modelling using 3 Classification Algorithms
# #### 1) Natural Language Processing
# #### 2) Random Forest
# #### 3) Logistic Regression

# %% [markdown]
# # NLP

# %%
import nltk

# %%
nltk.download('punkt') # downloaded the needed package
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vaishnavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.reset_index(inplace = True) # Resetting the index so that _unit_id is no longer my index.
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...            name  \
# 0    12/5/13 1:48  ...         sheezy0
# 1   10/1/12 13:51  ...     DavdBurnett
# ...

# %%
df = pd.concat([df.gender, df.text, df.description],axis =1) # concatenated  gender,text and description columns in order to perform nltk on them. 
df.head()
# Out:
#    gender                                               text  \
# 0    male  Robbie E Responds To Critics After Win Against...
# 1    male  ÛÏIt felt like friends I living story themÛ...
# 2    male  absolutely adore louis starts songs hits hard ...
# 3    male  Hi @JordanSpieth - Looking url - use @IFTTT?! ...
# 4  female  Watching Neighbours Sky+ catching Neighbs!! Xx...
#
#                                          description
# 0                                       sing rhythm.
# 1     I'm author novels filled family drama romance.
# 2                            louis whining squealing
# 3  Mobile guy. 49ers, Shazam, Google, Kleiner Per...
# 4  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...

# %%
df.gender = [1 if each == "female" else 0 for each in df.gender]
# changed the catagorical value of gender column female = 1 and male = 0.

# %%
df.head()
# Out:
#    gender                                               text  \
# 0       0  Robbie E Responds To Critics After Win Against...
# 1       0  ÛÏIt felt like friends I living story themÛ...
# 2       0  absolutely adore louis starts songs hits hard ...
# 3       0  Hi @JordanSpieth - Looking url - use @IFTTT?! ...
# 4       1  Watching Neighbours Sky+ catching Neighbs!! Xx...
#
#                                          description
# 0                                       sing rhythm.
# 1     I'm author novels filled family drama romance.
# 2                            louis whining squealing
# 3  Mobile guy. 49ers, Shazam, Google, Kleiner Per...
# 4  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...

# %%
df.shape
# Out:
# (12849, 3)

# %%
df['all_text'] = df['text'].str.cat(df['description'], sep="")

# %%
df.all_text[4]
# Out:
# 'Watching Neighbours Sky+ catching Neighbs!! Xxx _Ù÷Ä_Ù÷Ä_Ù÷Ä_ÙÔÎ_Ù\x8fÈ_ÙÔ\x8d_Ù\x8fÈ XxxRicky Wilson The Best FRONTMAN/Kaiser Chiefs The Best BAND Xxxx Thank Kaiser Chiefs incredible year gigs memories cherish always :) Xxxxxxx'

# %% [markdown]
# #### Regular Expression

# %%
import re

first_alltext=df.all_text[4]
all_text=re.sub("[^a-zA-Z]"," ",first_alltext)
all_text=all_text.lower()
all_text
# Out:
# 'watching neighbours sky  catching neighbs   xxx                              xxxricky wilson the best frontman kaiser chiefs the best band xxxx thank kaiser chiefs incredible year gigs memories cherish always    xxxxxxx'

# %% [markdown]
# #### Stopwords

# %%
import nltk #natural language tool kit
#nltk.download("stopwords")
from nltk.corpus import stopwords

all_text=nltk.word_tokenize(all_text) #shouldn't-> should n't

all_text=[word for word in all_text if not word in set(stopwords.words("english"))]

# %% [markdown]
# #### Lemmatization

# %%
import nltk as nlp
lema= nlp.WordNetLemmatizer()
all_text=[lema.lemmatize(word)for word in all_text]
all_text
# Out:
# ['watching',
#  'neighbour',
#  'sky',
#  'catching',
#  'neighbs',
#  'xxx',
#  'xxxricky',
#  'wilson',
#  'best',
#  'frontman',
#  'kaiser',
#  'chief',
#  'best',
#  'band',
#  'xxxx',
#  'thank',
#  'kaiser',
#  'chief',
#  'incredible',
#  'year',
#  'gig',
#  'memory',
#  'cherish',
#  'always',
#  'xxxxxxx']

# %%
all_text=" ".join(all_text)
all_text
# Out:
# 'watching neighbour sky catching neighbs xxx xxxricky wilson best frontman kaiser chief best band xxxx thank kaiser chief incredible year gig memory cherish always xxxxxxx'

# %% [markdown]
# #### Bag of Words

# %%
text_list=[]
for all_text in df.all_text:
    all_text=re.sub("[^a-zA-Z]"," ",all_text)
    all_text=all_text.lower()
    all_text=nltk.word_tokenize(all_text)
    lema= nlp.WordNetLemmatizer()
    all_text=[lema.lemmatize(word)for word in all_text]
    all_text=" ".join(all_text)
    text_list.append(all_text)
text_list
# Out:
# ['robbie e responds to critic after win against eddie edward in the worldtitleseries http t co nsybbmvjkzsing rhythm',
#  'it felt like friend i living story them http t co arnge yhno retired ian http t co cizcanpqfzi m author novel filled family drama romance',
#  'absolutely adore louis start song hit hard feel goodlouis whining squealing',
#  'hi jordanspieth looking url use ifttt don t typically see advanced user pgatour http t co h ou pe lmobile guy er shazam google kleiner perkins yahoo sprint pc airtouch air force stanford gsb uva dad husband brother golfer',
#  'watching neighbour sky catching neighbs xxx xxxricky wilson the best frontman kaiser chief the best band xxxx thank kaiser chief incredible year gig memory cherish always xxxxxxx',
#  'ive seen people train lamp chair tv etc http t co w zf pvm iknow me',
#  'gala bingo club bought m the uk s largest high street bingo operator gala taken by http t co hzeeykjud the secret getting ahead getting started',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
max_features=1000
count_vectorizer=CountVectorizer(max_features=max_features,stop_words="english")

sparse_matrix=count_vectorizer.fit_transform(text_list).toarray()
print("{} most common words: {}".format(max_features,count_vectorizer.get_feature_names()))
# Out:
# 1000 most common words: ['able', 'account', 'act', 'action', 'activist', 'actor', 'actually', 'add', 'addict', 'adult', 'adventure', 'advice', 'advocate', 'af', 'african', 'age', 'agent', 'ago', 'agree', 'ain', 'air', 'aka', 'album', 'alive', 'alum', 'amas', 'amazing', 'america', 'american', 'amp', 'analyst', 'angel', 'animal', 'anime', 'annoying', 'answer', 'anti', 'app', 'apparently', 'apple', 'area', 'arsenal', 'art', 'article', 'artist', 'artistoftheyear', 'ask', 'asked', 'aspiring', 'assistant', 'author', 'automatically', 'available', 'award', 'away', 'awesome', 'awkward', 'babe', 'baby', 'bacon', 'bad', 'bae', 'bag', 'ball', 'band', 'bank', 'bar', 'based', 'basically', 'basketball', 'bc', 'beach', 'bear', 'beat', 'beautiful', 'beauty', 'bed', 'beer', 'believe', 'best', 'better', 'bieber', 'big', 'biggest', 'bio', 'birthday', 'bit', 'bitch', 'black', 'blame', 'blessed', 'blog', 'blogger', 'blood', 'blue', 'board', 'body', 'bond', 'book', 'booking', 'born', 'bout', 'box', 'boy', 
# ...

# %% [markdown]
# #### Training and Testing the Model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# function to print individual train and test accuracy along with classification report and confusion matrix
def print_score(clf, X_train, Y_train, X_test, Y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(Y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(Y_train, pred) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(Y_train, pred) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(Y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(Y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X_test)
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(Y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(Y_test, pred) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(Y_test, pred) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(Y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(Y_test, pred)}\n")

# %%
y=df.iloc[:,0].values# male or females classes
x=sparse_matrix
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(x,y,test_size=0.1,random_state=42)
#naive bayes
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,Y_train)
#predict
Y_pred=nb.predict(X_test)
print("accuracy nlp: ",nb.score(Y_pred.reshape(-1,1),Y_test))
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(Y_test, Y_pred))
#evaluation
# Out:
# accuracy nlp:  0.5221789883268483
#               precision    recall  f1-score   support
#
#            0       0.61      0.52      0.56       614
#            1       0.61      0.69      0.65       671
#
#     accuracy                           0.61      1285
#    macro avg       0.61      0.61      0.61      1285
# weighted avg       0.61      0.61      0.61      1285

# %% [markdown]
# #### Accuracy

# %%
# calling the print_score function
print_score(nb, X_train, Y_train, X_test, Y_test, train=True)
print_score(nb, X_train, Y_train, X_test, Y_test, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 66.96%
# _______________________________________________
# Classification Report:	Precision Score: 66.23%
# 			Recall Score: 74.33%
# 			F1 score: 70.05%
# _______________________________________________
# Confusion Matrix:
#  [[3275 2278]
#  [1543 4468]]
#
# Test Result:
# ...
# Accuracy Score: 61.25%
# _______________________________________________
# Classification Report:	Precision Score: 61.43%
# 			Recall Score: 69.30%
# 			F1 score: 65.13%
# _______________________________________________
# Confusion Matrix:
#  [[322 292]
#  [206 465]]

# %%
test_score = accuracy_score(Y_test, nb.predict(X_test)) * 100
train_score = accuracy_score(Y_train, nb.predict(X_train)) * 100

results_df = pd.DataFrame(data=[["Natural Language Processing", train_score, test_score]], 
                          columns=['Model', 'Training Accuracy %', 'Testing Accuracy %'])
results_df
# Out:
#                          Model  Training Accuracy %  Testing Accuracy %
# 0  Natural Language Processing              66.9578           61.245136

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
# training on the same model as NLP on training data
rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rfc.predict(X_test) 
#predict
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(Y_test, y_pred))
#evaluation
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       614
#            1       0.65      0.65      0.65       671
#
#     accuracy                           0.64      1285
#    macro avg       0.64      0.64      0.64      1285
# weighted avg       0.64      0.64      0.64      1285

# %% [markdown]
# ### Accuracy

# %%
# call the print_score function
print_score(rfc, X_train, Y_train, X_test, Y_test, train=True)
print_score(rfc, X_train, Y_train, X_test, Y_test, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 98.48%
# _______________________________________________
# Classification Report:	Precision Score: 97.88%
# 			Recall Score: 99.22%
# 			F1 score: 98.55%
# _______________________________________________
# Confusion Matrix:
#  [[5424  129]
#  [  47 5964]]
#
# Test Result:
# ...
# Accuracy Score: 63.58%
# _______________________________________________
# Classification Report:	Precision Score: 65.13%
# 			Recall Score: 65.13%
# 			F1 score: 65.13%
# _______________________________________________
# Confusion Matrix:
#  [[380 234]
#  [234 437]]

# %%
test_score = accuracy_score(Y_test, rfc.predict(X_test)) * 100
train_score = accuracy_score(Y_train, rfc.predict(X_train)) * 100

new_row = {'Model':"Random Forest",'Training Accuracy %':train_score,'Testing Accuracy %': test_score}
results_df = results_df.append(new_row,ignore_index = True) 
#appending to the dataframe to compare the accuracy

# %%
results_df
# Out:
#                          Model  Training Accuracy %  Testing Accuracy %
# 0  Natural Language Processing            66.957800           61.245136
# 1                Random Forest            98.478035           63.579767

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
import pandas as pd

# %%
df=pd.read_csv('Information.csv', encoding = "ISO-8859-1")
#df contains the file information  which is in csv format

# %%
df['gender_gold'].isnull().sum()
#gives the total number of NaN values for the specified index
# Out:
# 20000

# %%
df.dropna(subset=['gender','gender:confidence'], how='any', inplace=True)
#drops the rows with NaN values for the specified indices

# %%
df.drop(df[df['gender']=='brand'].index,inplace=True)
df.drop(df[df['gender']=='unknown'].index,inplace=True)

# %%
df['tweet_coord'].isnull().sum()
# Out:
# 12816

# %%
df.drop(['tweet_coord','gender_gold', 'profile_yn_gold'], axis=1, inplace=True)

# %%
df['tweet_location'].fillna(value='unknown', inplace=True)
df['user_timezone'].fillna(value='unknown', inplace=True)
#to fill the NaN values for the specified indices with "unknown"

# %%
df['description'].fillna(value='Unknown',inplace=True)
df['_last_judgment_at'].fillna(value='Unknown',inplace=True)

# %%
df.set_index('_unit_id',inplace=True)

# %%
df['profile_yn'].unique() #no need to consider this as feature because its univalued
# Out:
# array(['yes'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder=LabelEncoder()

df['profile_yn']=label_encoder.fit_transform(df['profile_yn'])

# %%
df['_unit_state'].unique() #no need to consider this as feature because its univalued
# Out:
# array(['finalized', 'golden'], dtype=object)

# %%
df['_golden'].unique() #no need to consider this as feature because its univalued
# Out:
# array([False,  True])

# %%
df['gender']=label_encoder.fit_transform(df['gender'])
df['_unit_state']=label_encoder.fit_transform(df['_unit_state'])
df['_golden']=label_encoder.fit_transform(df['_golden'])

# %%
df.head()
# Out:
#            _golden  _unit_state  _trusted_judgments _last_judgment_at  gender  \
# _unit_id
# 815719226        0            0                   3    10/26/15 23:24       1
# 815719227        0            0                   3    10/26/15 23:30       1
# 815719228        0            0                   3    10/26/15 23:33       1
# 815719229        0            0                   3    10/26/15 23:10       1
# 815719230        0            0                   3     10/27/15 1:15       0
#
#            gender:confidence  profile_yn  profile_yn:confidence  \
# _unit_id
# 815719226             1.0000           0                    1.0
# 815719227             1.0000           0                    1.0
# 815719228             0.6625           0                    1.0
# 815719229             1.0000           0                    1.0
# 815719230             1.0000           0                    1.0
#
#                   created                                        description  \
# ...

# %%
#gender_confidence
#retweet_count
#Are the 2 features taken into consideration

# %%
df.drop(['_trusted_judgments','_golden','_unit_state','profile_yn'], axis=1)
# Out:
#           _last_judgment_at  gender  gender:confidence  profile_yn:confidence  \
# _unit_id
# 815719226    10/26/15 23:24       1             1.0000                    1.0
# 815719227    10/26/15 23:30       1             1.0000                    1.0
# 815719228    10/26/15 23:33       1             0.6625                    1.0
# 815719229    10/26/15 23:10       1             1.0000                    1.0
# 815719230     10/27/15 1:15       0             1.0000                    1.0
# ...                     ...     ...                ...                    ...
# 815757572           Unknown       0             1.0000                    1.0
# 815757681           Unknown       1             1.0000                    1.0
# 815757830           Unknown       1             1.0000                    1.0
# 815757921           Unknown       0             0.8489                    1.0
# 815757985           Unknown       0             1.0000                    1.0
#
# ...

# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
from sklearn import preprocessing
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
X = np.asarray(df[['gender:confidence','retweet_count']])
X[0:5]
# Out:
# array([[1.    , 0.    ],
#        [1.    , 0.    ],
#        [0.6625, 1.    ],
#        [1.    , 0.    ],
#        [1.    , 0.    ]])

# %%
y = np.asarray(df['gender'])
y [0:5]
# Out:
# array([1, 1, 1, 1, 0])

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 0.50697159, -0.04395904],
#        [ 0.50697159, -0.04395904],
#        [-1.53369911,  0.61206864],
#        [ 0.50697159, -0.04395904],
#        [ 0.50697159, -0.04395904]])

# %%
#we split our dataset into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (10315, 2) (10315,)
# Test set: (2579, 2) (2579,)

# %% [markdown]
# Modeling (Logistic Regression with Scikit-learn)
#
# Lets build our model using LogisticRegression from Scikit-learn package. This function implements logistic regression and can use different numerical optimizers to find parameters, including ‘newton-cg’, ‘lbfgs’, ‘liblinear’, ‘sag’, ‘saga’ solvers. You can find extensive information about the pros and cons of these optimizers if you search it in internet.
#
# The version of Logistic Regression in Scikit-learn, support regularization. Regularization is a technique used to solve the overfitting problem in machine learning models. C parameter indicates inverse of regularization strength which must be a positive float. Smaller values specify stronger regularization. Now lets fit our model with train set:

# %%
#Modeling (Logistic Regression with Scikit-learn)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = LR.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
#predict_proba returns estimates for all classes, ordered by the label of classes. So, the first column is 
#the probability of class 1, P(Y=1|X), and second column is probability of class 0, P(Y=0|X):
# Out:
# array([[0.47899568, 0.52100432],
#        [0.48159238, 0.51840762],
#        [0.52749855, 0.47250145],
#        ...,
#        [0.53408576, 0.46591424],
#        [0.53408576, 0.46591424],
#        [0.53408576, 0.46591424]])

# %%
#Evaluation
#jaccard index
#If the entire set of predicted labels for a sample strictly match
#with the true set of labels, then the subset accuracy is 1.0; otherwise it is 0.0.
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, y_pred)
# Out:
# C:\Users\vaishnavi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:664: FutureWarning: jaccard_similarity_score has been deprecated and replaced with jaccard_score. It will be removed in version 0.23. This implementation has surprising behavior for binary and multiclass classification tasks.
#   FutureWarning)
# 0.5494377665761924

# %%
LR.score(X_test,y_test) #The accuracy for Lofistic Regression is 54.94% ie 55%
# Out:
# 0.5494377665761924

# %%
#confusion matrix
#Another way of looking at accuracy of classifier is to look at confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
print(confusion_matrix(y_test, y_pred, labels=[1,0]))
# Out:
# [[ 340  912]
#  [ 250 1077]]

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred, labels=[1,0])
np.set_printoptions(precision=2)


# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['gender=1','gender=0'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 340  912]
#  [ 250 1077]]

# %%
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.81      0.65      1327
#            1       0.58      0.27      0.37      1252
#
#     accuracy                           0.55      2579
#    macro avg       0.56      0.54      0.51      2579
# weighted avg       0.56      0.55      0.51      2579

# %% [markdown]
# # To implement Logistic Regression without sklearn

# %% [markdown]
# class LogisticRegression:
#     def __init__(self, lr=0.01, num_iter=100000, fit_intercept=True, verbose=False):
#         self.lr = lr
#         self.num_iter = num_iter
#         self.fit_intercept = fit_intercept
#         self.verbose = verbose
#
#     def __add_intercept(self, X):
#         intercept = np.ones((X.shape[0], 1))
#         return np.concatenate((intercept, X), axis=1)
#
#     def __sigmoid(self, z):
#         return 1 / (1 + np.exp(-z))
#     def __loss(self, h, y):
#         return (-y * np.log(h) - (1 - y) * np.log(1 - h)).mean()
#
#     def fit(self, X, y):
#         if self.fit_intercept:
#             X = self.__add_intercept(X)
#
#         # weights initialization
#         self.theta = np.zeros(X.shape[1])
#
#         for i in range(self.num_iter):
#             z = np.dot(X, self.theta)
#             h = self.__sigmoid(z)
#             gradient = np.dot(X.T, (h - y)) / y.size
#             self.theta -= self.lr * gradient
#
#             z = np.dot(X, self.theta)
#             h = self.__sigmoid(z)
#             loss = self.__loss(h, y)
#
#             if(self.verbose ==True and i % 10000 == 0):
#                 print(f'loss: {loss} \t')
#
#     def predict_prob(self, X):
#         if self.fit_intercept:
#             X = self.__add_intercept(X)
#
#         return self.__sigmoid(np.dot(X, self.theta))
#
#     def predict(self, X):
#         return self.predict_prob(X).round()

# %% [markdown]
# ### Modeling and prediction

# %% [markdown]
# model = LogisticRegression(lr=0.1, num_iter=300000)
# %time model.fit(X, y)
#
#
# preds = model.predict(X)
# (preds == y).mean()
# model.theta

# %%
test_score = accuracy_score(y_test, LR.predict(X_test)) * 100
train_score = accuracy_score(y_train, LR.predict(X_train)) * 100

new_row2 = {'Model':"Logistic Regression",'Training Accuracy %':train_score,'Testing Accuracy %': test_score}
results_df = results_df.append(new_row2,ignore_index = True) 
#appending to the dataframe to compare the accuracy

# %%
results_df
# Out:
#                          Model  Training Accuracy %  Testing Accuracy %
# 0  Natural Language Processing            66.957800           61.245136
# 1                Random Forest            98.478035           63.579767
# 2          Logistic Regression            53.339796           54.943777

# %% [markdown]
# ##### So, among the 3 classification algorithms used above, it is observed that Random Forest model gives 63% accuracy followed by  and NLP (61%) and Logistic Regression (55%)
